# %%
import pandas as pd

# %%
df = pd.read_excel("../05. Database RP May 2025 - AC REGISTER.xlsx", sheet_name="Raw", skiprows=1)
df = df.iloc[:, 1:]
df.head()
# Out:
#    YEAR PERIODE AIRCRAFT TYPE    FLIGHT NUMBER_CITYPAIR SERVICE TYPE  \
# 0  2024     JAN         AC738  GA0072.CGK-TKG.[CGK-TKG]          DOM
# 1  2024     JAN         AC738  GA0072.CGK-TKG.[CGK-TKG]          DOM
# 2  2024     JAN         AC738  GA0072.CGK-TKG.[CGK-TKG]          DOM
# 3  2024     JAN         AC738  GA0072.CGK-TKG.[CGK-TKG]          DOM
# 4  2024     JAN         AC738  GA0072.CGK-TKG.[CGK-TKG]          DOM
#
#    SUB-SERVICE ROUNDTRIPROUTE FLIGHT ROUTE AC REG      DATE  ...  \
# 0  DOM_2 (JKT)    CGK-TKG-CGK      CGK-TKG  PKGNR  30012024  ...
# 1  DOM_2 (JKT)    CGK-TKG-CGK      CGK-TKG  PKGFJ  31012024  ...
# 2  DOM_2 (JKT)    CGK-TKG-CGK      CGK-TKG  PKGNA   1012024  ...
# 3  DOM_2 (JKT)    CGK-TKG-CGK      CGK-TKG  PKGNR   2012024  ...
# 4  DOM_2 (JKT)    CGK-TKG-CGK      CGK-TKG  PKGMW  19012024  ...
#
#    RPK (000) C CLASS  RPK (000) Y CLASS  OTHER REVENUE PASSENGER  \
# 0              0.573             28.268               382.164660
# ...

# %%
cols = ["YEAR", "PERIODE", "AIRCRAFT TYPE", "FLIGHT NUMBER_CITYPAIR", "SERVICE TYPE", "SUB-SERVICE", 
        "ROUNDTRIPROUTE", "FLIGHT ROUTE", "AC REG", "Region", "QUARTER", "GA Service","AIRCRAFT TYPE GROUPING"]

# %%
df1 = df.loc[:, cols]
df1.drop_duplicates(inplace=True)

# %%
unique_dict = {col: df1[col].unique().tolist() for col in df1.columns}

# Find the maximum length among all unique value lists
max_len = max(len(v) for v in unique_dict.values())

# Pad lists with None to ensure all have the same length
for col in unique_dict:
    unique_dict[col].extend([None] * (max_len - len(unique_dict[col])))

# Create the new DataFrame
unique_df = pd.DataFrame(unique_dict)
unique_df
# Out:
#         YEAR PERIODE AIRCRAFT TYPE    FLIGHT NUMBER_CITYPAIR SERVICE TYPE  \
# 0     2024.0     JAN         AC738  GA0072.CGK-TKG.[CGK-TKG]          DOM
# 1     2025.0     FEB         AC773  GA0073.TKG-CGK.[TKG-CGK]          INT
# 2        NaN     MAR         AC73G  GA0088.CGK-AMS.[CGK-AMS]         None
# 3        NaN     APR         AC330  GA0089.AMS-CGK.[AMS-CGK]         None
# 4        NaN     MAY         AC33R  GA0102.CGK-PLM.[CGK-PLM]         None
# ...      ...     ...           ...                       ...          ...
# 1083     NaN    None          None  GA0830.CGK-SIN.[CGK-SIN]         None
# 1084     NaN    None          None  GA1800.CGK-MES.[CGK-MES]         None
# 1085     NaN    None          None  GA6004.CGK-UPG.[CGK-UPG]         None
# 1086     NaN    None          None  GA4022.CGK-DPS.[CGK-DPS]         None
# 1087     NaN    None          None  GA4344.AMI-CGK.[AMI-CGK]         None
#
#           SUB-SERVICE ROUNDTRIPROUTE FLIGHT ROUTE AC REG    Region QUARTER  \
# ...

# %%
len(unique_df)
# Out:
# 1088

# %%
unique_df.to_csv("df_filter1.csv", index=False)
